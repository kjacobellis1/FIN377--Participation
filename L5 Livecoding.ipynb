# %% [markdown]
# # Numpy
# - Created in order to do stuff quickly (speed & math functions)

# %%
import seaborn as sns #seaborn - how we will use most of our plotting

iris = sns.load_dataset('iris')

iris

# iris.tail(10) #prints the last 10 rows
# iris.head(10) #prints the first 10 rows
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# ...

# %%
iris.shape #shape is an attribute
# Out:
# (150, 5)

# %%
iris.describe() #only gives info about numerical columns
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris['species'].value_counts() #give me info about the species and count how many are in each
# Out:
# setosa        50
# virginica     50
# versicolor    50
# Name: species, dtype: int64

# %%
iris['species'].nunique() #tells you how many different unique values are in the species
# Out:
# 3

# %% [markdown]
# # Got - Baby Names

# %%
#TO USE datadotworld PACKAGE:
#1. create account at data.world, then run the next two lines:
#2. in terminal/powershell: pip install datadotworld[pandas]
#
#   IF THIS DOESN'T WORK BC YOU GET AN ERROR ABOUT "CCHARDET", RUN:
#    conda install -c conda-forge cchardet
#   THEN RERUN: pip install datadotworld[pandas] 
#
#3. in terminal/powershell: dw configure          
#3a. copy in API token from data.world (get from settings > advanced)

import datadotworld as dw
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

baby_names = dw.load_dataset('nkrishnaswami/us-ssa-baby-names-national')
baby_names = baby_names.dataframes['names_ranks_counts']

# %%
baby_names
baby_names.head(10)
baby_names.shape
# Out:
# (1956698, 5)

# %%
#look at number variables
baby_names.describe() #does it all make sense? any data issues?

#look at caregory variables
baby_names['sex'].value_counts() # this isnt 50/50!... but thats ok
baby_names['sex'].nunique() 
baby_names['year'].value_counts()
# Out:
# 2008    35070
# 2007    34950
# 2009    34702
# 2006    34082
# 2010    34067
# 2011    33903
# 2012    33732
# 2013    33269
# 2014    33228
# 2015    33098
# 2016    32979
# 2005    32546
# 2017    32469
# 2004    32046
# 2018    32033
# 2003    31183
# 2002    30563
# 2001    30269
# 2000    29769
# 1999    28550
# 1998    27899
# 1997    26971
# 1996    26423
# 1995    26080
# 1994    25995
# 1993    25966
# 1992    25427
# 1991    25105
# 1990    24719
# 1989    23773
#         ...
# 1909     4227
# 1908     4018
# 1907     3948
# 1900     3730
# 1905     3655
# 1906     3633
# 1904     3560
# 1903     3389
# 1902     3362
# 1898     3264
# 1901     3153
# 1896     3091
# 1895     3049
# 1899     3042
# 1897     3028
# 1894     2941
# 1892     2921
# 1893     2831
# 1890     2695
# 1891     2660
# 1888     2651
# 1889     2590
# 1886     2392
# 1887     2373
# 1884     2297
# 1885     2294
# 1882     2127
# 1883     2084
# 1880     2000
# 1881     1935
# ...

# %%
#lets count Johns over time... 

somenames = baby_names.loc[baby_names['name'] == 'John']
combined = somenames.groupby(['name','year'])['count'].sum().reset_index() #split the entire data set up  #.sum sums every observation within the group --> ex: John 1990 7; John 1991 12 --> then combine
combined #reset index to turn year into a variable!!
sns.lineplot(data=combined, x='year', y='count')
# Out:
#      name  year  count
# 0    John  1880   9701
# 1    John  1881   8795
# 2    John  1882   9597
# 3    John  1883   8934
# 4    John  1884   9428
# 5    John  1885   8801
# 6    John  1886   9074
# 7    John  1887   8166
# 8    John  1888   9299
# 9    John  1889   8600
# 10   John  1890   8558
# 11   John  1891   7724
# 12   John  1892   9093
# 13   John  1893   8110
# 14   John  1894   8298
# 15   John  1895   8381
# 16   John  1896   8188
# 17   John  1897   7596
# 18   John  1898   8214
# 19   John  1899   7030
# 20   John  1900   9875
# 21   John  1901   6939
# 22   John  1902   7945
# 23   John  1903   7649
# 24   John  1904   8148
# 25   John  1905   8103
# 26   John  1906   8308
# 27   John  1907   9048
# 28   John  1908   9400
# 29   John  1909   9658
# ..    ...   ...    ...
# 109  John  1989  29978
# 110  John  1990  29154
# 111  John  1991  27864
# 112  John  1992  26297
# 113  John  1993  25058
# 114  John  1994  24226
# 115  John  1995  23281
# 116  John  1996  22217
# ...

# %%
# look at arya and sansa # just copy data set from above

somenames = baby_names.loc[baby_names['name'] == 'Arya']
combined = somenames.groupby(['name','year'])['count'].sum().reset_index() 
combined 
#sns.lineplot(data=combined, x='year', y='count')
# Out:
#     name  year  count
# 0   Arya  1982     12
# 1   Arya  1983      7
# 2   Arya  1984      9
# 3   Arya  1985     20
# 4   Arya  1986     23
# 5   Arya  1987     22
# 6   Arya  1988     27
# 7   Arya  1989     30
# 8   Arya  1990     36
# 9   Arya  1991     34
# 10  Arya  1992     36
# 11  Arya  1993     26
# 12  Arya  1994     15
# 13  Arya  1995     30
# 14  Arya  1996     36
# 15  Arya  1997     44
# 16  Arya  1998     58
# 17  Arya  1999     47
# 18  Arya  2000     81
# 19  Arya  2001     84
# 20  Arya  2002    133
# 21  Arya  2003    157
# 22  Arya  2004    204
# 23  Arya  2005    195
# 24  Arya  2006    265
# 25  Arya  2007    304
# 26  Arya  2008    319
# 27  Arya  2009    349
# 28  Arya  2010    361
# 29  Arya  2011    498
# 30  Arya  2012    836
# 31  Arya  2013   1215
# 32  Arya  2014   1635
# 33  Arya  2015   1731
# 34  Arya  2016   1949
# 35  Arya  2017   2201
# 36  Arya  2018   2594

# %%
names_i_want = (baby_names['name'] == 'Sansa') | (baby_names['name'] == 'Arya')  # | means 'or' to pandas
names_i_want.sum() #only 6 years where there is a Sansa, additional 64 Aryas
somenames = baby_names.loc[names_i_want]
combined = somenames.groupby(['name','year'])['count'].sum().reset_index() 
combined 
sns.lineplot(data=combined, x='year', y='count', hue='name')

# %%
# QUERY!!
somenames = baby_names.query('name in ["Arya","Sansa"]') # query needs a string with true/false conditions
combined = somenames.groupby(['name','year'])['count'].sum().reset_index() 
combined 
sns.lineplot(data=combined, x='year', y='count', hue='name')

# %%
# i dont want "somenames"
(
    baby_names
    .query('name in ["Arya","Sansa"]') #get a subsample
    .groupby(['name','year'])['count'].sum().reset_index() #combine M-F
                                         # "pipe" in a function to apply to this object
                                        # syntax: <function>, arg1, arg2, etc...
                                        # call the function and tell it that 
                                        # the object in memory goes to the parameter 'data'
    .pipe((sns.lineplot, 'data'),hue='name',x='year',y='count')
) #everything in the middle of the parenthesis is one line of code

# %% [markdown]
# # Your Turn - FRED (from Federal Reserve) data

# %%
import datetime
import pandas_datareader as pdr


start = datetime.datetime(2010, 1, 1) # you can specify start and end dates this way
end = datetime.datetime(2013, 1, 27)
macro_df = pdr.data.DataReader(['GDP','CPIAUCSL'], 'fred', start, end)
macro_df

#Q: What is the second series? -- CPI 
#Q2: What is the frequency of the series?
#Q3: What is the average ANNUAL GDP?
# Out:
#                   GDP  CPIAUCSL
# DATE
# 2010-01-01  14721.350   217.488
# 2010-02-01        NaN   217.281
# 2010-03-01        NaN   217.353
# 2010-04-01  14926.098   217.403
# 2010-05-01        NaN   217.290
# 2010-06-01        NaN   217.199
# 2010-07-01  15079.917   217.605
# 2010-08-01        NaN   217.923
# 2010-09-01        NaN   218.275
# 2010-10-01  15240.843   219.035
# 2010-11-01        NaN   219.590
# 2010-12-01        NaN   220.472
# 2011-01-01  15285.828   221.187
# 2011-02-01        NaN   221.898
# 2011-03-01        NaN   223.046
# 2011-04-01  15496.189   224.093
# 2011-05-01        NaN   224.806
# 2011-06-01        NaN   224.806
# 2011-07-01  15591.850   225.395
# 2011-08-01        NaN   226.106
# 2011-09-01        NaN   226.597
# 2011-10-01  15796.460   226.750
# 2011-11-01        NaN   227.169
# 2011-12-01        NaN   227.223
# 2012-01-01  16019.758   227.842
# 2012-02-01        NaN   228.329
# 2012-03-01        NaN   228.807
# 2012-04-01  16152.257   229.187
# ...

# %%
#Q4: Download the annual real gdp from 1960 to 2018 from FRED and compute the average annual percent change
macro_df = pdr.data.DataReader(['GDPCA'], 'fred', start, end)

# %%
macro_df.describe()
# Out:
#               GDPCA
# count      4.000000
# mean   16032.948250
# std      394.227925
# min    15598.753000
# 25%    15780.186250
# 50%    16018.835500
# 75%    16271.597500
# max    16495.369000

# %%
#Q5: Compute the average gdp percent change within each decade
macro_df['GDPCA'].pct_change().describe() #answer is 3.07
#create a variable called decade & pct change
# Out:
# count    3.000000
# mean     0.018808
# std      0.003510
# min      0.015508
# 25%      0.016965
# 50%      0.018421
# 75%      0.020458
# max      0.022495
# Name: GDPCA, dtype: float64
